# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
np.set_printoptions(threshold=np.nan)
from scipy import stats
results = []
resi = []

f  = open('ecmsm_12017-01-12 11.55.45.265_A0000.csv') 

csv_f = csv.reader(f)

for row in csv_f:
    results.append(row)
    
f.close()    
#     reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
#     interestingrows=[row for idx, row in enumerate(reader) if idx in range(4,10004)]    
#     for row in reader: # each row is a list
#          results.append(row)

# with open('file.csv') as fd:
#     reader=csv.reader(ecmsm_12017-01-12 11.55.45.265_A0000.csv)
#     interestingrows=[row for idx, row in enumerate(reader) if idx in range(4,10004)]

# %%
print(results[3])
# Out:
# ['   2188.814985', '   0.201981']

# %%
for i in range(3,100003):
    resi.append(results[i][1])

# %%
print(resi)
# Out:
# ['   0.201981', '   0.201987', '   0.201987', '   0.201971', '   0.201982', '   0.201960', '   0.201965', '   0.201988', '   0.201959', '   0.201992', '   0.201989', '   0.201976', '   0.201982', '   0.201985', '   0.201962', '   0.201982', '   0.201982', '   0.202008', '   0.201997', '   0.202020', '   0.202013', '   0.201998', '   0.202003', '   0.202031', '   0.202037', '   0.202040', '   0.202031', '   0.202046', '   0.202057', '   0.202022', '   0.202060', '   0.202052', '   0.202058', '   0.202073', '   0.202080', '   0.202087', '   0.202073', '   0.202089', '   0.202065', '   0.202078', '   0.202070', '   0.202090', '   0.202070', '   0.202092', '   0.202095', '   0.202078', '   0.202082', '   0.202092', '   0.202086', '   0.202092', '   0.202096', '   0.202081', '   0.202078', '   0.202120', '   0.202125', '   0.202134', '   0.202126', '   0.202123', '   0.202130', '   0.202124', '   0.202096', '   0.202141', '   0.202134', '   0.202174', '   0.202150', '   0.202173', '   0.2
# ...

# %%
new_resi = []
for item in resi:
    new_resi.append(float(item))

# %%
print(new_resi)
# Out:
# [0.201981, 0.201987, 0.201987, 0.201971, 0.201982, 0.20196, 0.201965, 0.201988, 0.201959, 0.201992, 0.201989, 0.201976, 0.201982, 0.201985, 0.201962, 0.201982, 0.201982, 0.202008, 0.201997, 0.20202, 0.202013, 0.201998, 0.202003, 0.202031, 0.202037, 0.20204, 0.202031, 0.202046, 0.202057, 0.202022, 0.20206, 0.202052, 0.202058, 0.202073, 0.20208, 0.202087, 0.202073, 0.202089, 0.202065, 0.202078, 0.20207, 0.20209, 0.20207, 0.202092, 0.202095, 0.202078, 0.202082, 0.202092, 0.202086, 0.202092, 0.202096, 0.202081, 0.202078, 0.20212, 0.202125, 0.202134, 0.202126, 0.202123, 0.20213, 0.202124, 0.202096, 0.202141, 0.202134, 0.202174, 0.20215, 0.202173, 0.202167, 0.202141, 0.202151, 0.202168, 0.202149, 0.202155, 0.202141, 0.202158, 0.202182, 0.202157, 0.202152, 0.202186, 0.202166, 0.202204, 0.202177, 0.202218, 0.202186, 0.202197, 0.202184, 0.202191, 0.202199, 0.202191, 0.202186, 0.202197, 0.202163, 0.202179, 0.202185, 0.202167, 0.202182, 0.202184, 0.202189, 0.202194, 0.202204, 0.202184, 0.202179
# ...

# %%
new_resi = np.array(new_resi)

# %%
print(new_resi[0] * 2)
# Out:
# 0.403962

# %%
import pandas as pd 
df = pd.DataFrame(new_resi)
df.to_csv("file_path.csv")

# %%
print(resi[0])
# Out:
# 32
